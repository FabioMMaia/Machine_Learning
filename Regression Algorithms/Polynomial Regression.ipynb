# %% [markdown]
# # Polynomial Linear Regression

# %%
#Import Libraries
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
#Import data
dataset=pd.read_csv(r"../../Data Science/Cursos Online/Udemy/Machine-Learning-A-Z-New/Machine Learning A-Z New" \
                    "/Part 2 - Regression/Section 6 - Polynomial Regression/Position_Salaries.csv")
X=dataset.iloc[:,1:2].values
y=dataset.iloc[:,-1].values

# Splitting training and testing
# from sklearn.model_selection import train_test_split as tts
# X_train, X_test, y_train, y_test= tts(X,y, test_size=1/3, random_state=0)

# Feature Scaling
# from sklearn.preprocessing import StandardScaler
# sc_X=StandardScaler()
# X_train=sc_X.fit_transform(X_train)
# X_test=sc_X.transform(X_test)

# %%
plt.plot(dataset.iloc[:,0],y,'o')
plt.xticks(dataset.iloc[:,0], rotation=90)
plt.ylabel(dataset.columns[-1])
plt.subplots_adjust(bottom=0.15)

# %%
lin=LinearRegression()
lin.fit(X, y)
y_pred_lin=lin.predict(X)

print('Linear Regression\n')
print('Mean percentual error: {0:.2f}%.'.format(100*np.mean((y-y_pred_lin)/y)))
print('Entire dataset: {0:.5f}'.format(lin.score(X, y)))
# Out:
# Linear Regression
#
# Mean percentual error: 19.52%.
# Entire dataset: 0.66904

# %%
pol= PolynomialFeatures(degree=4)
# print (dir(pol))
X_poly=pol.fit_transform(X)

lin_pol=LinearRegression()
lin_pol.fit(X_poly, y)
y_pred_pol=lin_pol.predict(X_poly)

print('Polinomial Linear Regression\n')
print('Mean percentual error: {0:.2f}%'.format(100*np.mean((y-y_pred_pol)/y)))
print('Entire dataset: {0:.5f}'.format(lin_pol.score(X_poly, y)))
# Out:
# Polinomial Linear Regression
#
# Mean percentual error: 0.24%
# Entire dataset: 0.99739

# %%
X_grid=np.arange(min(X),max(X),0.1)
X_grid=X_grid.reshape(-1,1)

plt.plot(dataset.iloc[:,0],y,'o')
plt.plot(dataset.iloc[:,0],y_pred_lin,)
# plt.plot(dataset.iloc[:,0],y_pred_pol,)
plt.plot(X_grid,lin_pol.predict(pol.fit_transform(X_grid)),)
plt.xticks(dataset.iloc[:,0], rotation=90)
plt.ylabel(dataset.columns[-1])
plt.subplots_adjust(bottom=0.15)

# line=np.arange(1,11)
# lin.coef_[0]+lin.coef_[1]*line + lin.coef_[2]*line

# %%
print (dir(lin))

# %%
### Building a Regression Template ###

#Import Libraries
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

#Import data
dataset=pd.read_csv(r'../../Data Science/Cursos Online/Udemy/Machine-Learning-A-Z-New/Machine Learning A-Z New/Part 2 - Regression/Section 6 - Polynomial Regression/Position_Salaries.csv')
X=dataset.iloc[:,1:-1].values
y=dataset.iloc[:,-1].values

# Splitting training and testing
from sklearn.model_selection import train_test_split as tts
X_train, X_test, y_train, y_test= tts(X,y, test_size=1/3, random_state=0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X=StandardScaler()
X_train=sc_X.fit_transform(X_train)
X_test=sc_X.transform(X_test)

#Definining Linear Regression model
lin=LinearRegression()
lin.fit(X_train, y_train)
y_pred=lin.predict(X_test)

print('Linear Regression')
print('Score in the entire dataset: {0:.5f}'.format(lin.score(X, y)))
print('Score in the training dataset: {0:.5f}'.format(lin.score(X_train, y_train)))
print('Score in the entire dataset: {0:.5f}\n'.format(lin.score(X_test, y_test)))

# %%
### Building a Polinomial Regression Template ###

#Import Libraries
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

#Import data
dataset=pd.read_csv(r'../../Data Science/Cursos Online/Udemy/Machine-Learning-A-Z-New/Machine Learning A-Z New/Part 2 - Regression/Section 6 - Polynomial Regression/Position_Salaries.csv')
X=dataset.iloc[:,1:-1].values
y=dataset.iloc[:,-1].values

#Definining Linear Regression model
lin=LinearRegression()
lin.fit(X, y)
y_pred_lin=lin.predict(X)

#Definining Polinomial Regression model (for n =4)
pol= PolynomialFeatures(degree=4)
X_poly=pol.fit_transform(X)

# Splitting training and testing (for the polinomial transformation)
from sklearn.model_selection import train_test_split as tts
X_train, X_test, y_train, y_test= tts(X_poly,y, test_size=1/3, random_state=0)

# Feature Scaling
# from sklearn.preprocessing import StandardScaler
# sc_X=StandardScaler()
# X_train=sc_X.fit_transform(X_train)
# X_test=sc_X.transform(X_test)

#Applyng Linear Regression for the polinomial transformed dataset
lin_pol=LinearRegression()
lin_pol.fit(X_poly, y)
y_pred=lin_pol.predict(X_poly)

#Printing results
print('Polinomial Linear Regression')
print('Score entire dataset: {0:.5f}'.format(lin_pol.score(X_poly, y)))
print('Score in the training dataset: {0:.5f}'.format(lin_pol.score(X_train, y_train)))
print('Score in the entire dataset: {0:.5f}\n'.format(lin_pol.score(X_test, y_test)))
# Out:
# Polinomial Linear Regression
# Score entire dataset: 0.99739
# Score in the training dataset: 0.97964
# Score in the entire dataset: 0.99809

# %%
### Building a Regression Template ###

# Import Libraries
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# Import data
dataset=pd.read_csv(r'../../Data Science/Cursos Online/Udemy/Machine-Learning-A-Z-New/Machine Learning A-Z New/Part 2 - Regression/Section 6 - Polynomial Regression/Position_Salaries.csv')
X=dataset.iloc[:,1:-1].values
y=dataset.iloc[:,-1].values

# Splitting training and testing (for the polinomial transformation)
from sklearn.model_selection import train_test_split as tts
X_train, X_test, y_train, y_test= tts(X,y, test_size=1/3, random_state=0)

# Feature Scaling
# from sklearn.preprocessing import StandardScaler
# sc_X=StandardScaler()
# X_train=sc_X.fit_transform(X_train)
# X_test=sc_X.transform(X_test)
# sc_y=StandardScaler()
# y_train=sc_y.fit_transform(y_train)

# Fitting the Regression Model to the Dataset
model='NA'

# Predicting a new result with Regression Model
y_pred=regressor.predict(X_test)

# Visualising the Regression Model Result
X_grid=np.arange(min(X),max(X),0.1)
X_grid=X_grid.reshape(-1,1)

plt.scatter(X,y,'o')
plt.plot(X,regressor.predict(X), color='red')
plt.plot(X_grid,regressor.predict(X_grid), color='blue')
plt.title('Regression Model')
plt.xlabel('X')
plt.ylabel('y')
plt.subplots_adjust(bottom=0.15)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-144f538e95e4> in <module>
#      30
#      31 # Predicting a new result with Regression Model
# ---> 32 y_pred=regressor.predict(X_test)
#      33
#      34 # Visualising the Regression Model Result
#
# NameError: name 'regressor' is not defined
