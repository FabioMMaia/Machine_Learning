# %%
# GERAL
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_boston

# %%
# MODELAGEM
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# MODELO
from sklearn.linear_model import RidgeCV, LassoCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor,RandomForestRegressor
from sklearn.ensemble import StackingRegressor

# %%
load_df = load_boston()
dataset = pd.concat([pd.DataFrame(load_df.data,columns = load_df.feature_names).add_prefix('X_')
                     ,pd.DataFrame(load_df.target,columns = ['target'])], axis=1)

# %%
estimators = [('ridge', RidgeCV()),
              ('lasso', LassoCV(random_state=42)),
              ('knr', KNeighborsRegressor(n_neighbors=20,metric='euclidean'))]

# %%
final_estimator = GradientBoostingRegressor(n_estimators=25,
                                            subsample=0.5,
                                            min_samples_leaf=25, 
                                            max_features=1, 
                                            random_state=42)

reg = StackingRegressor(estimators=estimators,
                        final_estimator=final_estimator)

# %%
X_train, X_test, y_train, y_test = train_test_split(dataset.filter(like='X_'), dataset['target'],random_state=42)
reg.fit(X_train, y_train)
# Out:
# StackingRegressor(cv=None,
#                   estimators=[('ridge',
#                                RidgeCV(alphas=array([ 0.1,  1. , 10. ]),
#                                        cv=None, fit_intercept=True,
#                                        gcv_mode=None, normalize=False,
#                                        scoring=None, store_cv_values=False)),
#                               ('lasso',
#                                LassoCV(alphas=None, copy_X=True, cv=None,
#                                        eps=0.001, fit_intercept=True,
#                                        max_iter=1000, n_alphas=100, n_jobs=None,
#                                        normalize=False, positive=False,
#                                        precompute='auto', random_s...
#                                                             max_depth=3,
#                                                             max_features=1,
#                                                             max_leaf_nodes=None,
#                                                             min_impurity_decrease=0.0,
#                                                             min_impurity_split=None,
#                                                             min_samples_leaf=25,
#                                                             min_samples_split=2,
#                                                             min_weight_fraction_leaf=0.0,
#                                                             n_estimators=25,
#                                                             n_iter_no_change=None,
#                                                             presort='deprecated',
#                                                             random_state=42,
#                                                             subsample=0.5,
#                                                             tol=0.0001,
#                                                             validation_fraction=0.1,
#                                                             verbose=0,
#                                                             warm_start=False),
#                   n_jobs=None, passthrough=False, verbose=0)

# %%
y_pred = reg.predict(X_test)

# %%
y_pred
# Out:
# array([25.9271049 , 38.48913878, 12.09805488, 23.52389065, 16.80033124,
#        21.74847934, 18.77919867, 12.69894965, 19.71166145, 20.82316827,
#        21.50116069, 19.90266201, 11.91753838, 21.65500634, 20.68319729,
#        24.18015222, 19.98908563, 11.91753838, 38.28659275, 15.09246894,
#        23.64656434, 26.36304436, 16.56965826, 24.38340216, 15.87388021,
#        15.89349739, 21.7217799 , 12.09805488, 20.70844197, 20.1153618 ,
#        21.85605626, 24.33120737, 18.92198572, 19.41624447, 13.83862812,
#        19.45354956, 31.62135651, 20.64062896, 21.77967552, 23.71409706,
#        16.93271406, 30.80367213, 38.28659275, 18.36400415, 24.09599178,
#        15.09246894, 16.75017476, 23.63222957, 16.91705419, 26.14470439,
#        21.8059593 , 38.28659275, 16.0630013 , 24.27853108, 38.48913878,
#        21.85605626, 16.40229589, 34.23716166, 24.59975953, 16.93271406,
#        22.70147359, 30.28378495, 31.01643783, 17.82536289, 20.61574799,
#        16.51158938, 16.40229589, 24.09599178, 30.28378495, 11.91753838,
#        20.22374643, 24.18015222, 13.20889704, 18.55650593, 21.80176356,
#        11.91753838, 20.85154383, 38.28659275, 15.08732776, 13.20889704,
#        20.34353095, 12.69894965, 20.95529756, 11.91753838, 21.99893542,
#        29.10005582, 17.31027863, 24.09599178, 25.39200522, 19.06676958,
#        24.09599178, 11.91753838, 20.95744463, 18.0079022 , 17.62761807,
#        20.95744463, 24.3576366 , 11.91753838, 12.09805488, 11.91753838,
#        21.5392406 , 21.78638493, 15.08425999, 20.4420385 , 24.01303263,
#        11.91753838, 19.31269868, 23.63222957, 21.05172022, 23.1514232 ,
#        11.91753838, 14.68862061, 23.20571591, 24.75325973, 32.58102184,
#        12.26755879, 38.28659275, 16.93271406, 20.64062896, 24.09130409,
#        19.22613733, 23.63999761, 11.91753838, 23.69316083, 23.38562849,
#        24.01303263, 24.83236525])

# %%
from sklearn.metrics import r2_score
print('R2 score: {:.2f}'.format(r2_score(y_test, y_pred)))
# Out:
# R2 score: 0.75

# %%
reg.transform(X_test.iloc[:5,:])
# Out:
# array([[28.78639573, 28.433658  , 24.31      ],
#        [35.96334615, 32.58788457, 26.73      ],
#        [14.97187156, 14.05965525, 14.89      ],
#        [25.19918851, 25.54000515, 26.245     ],
#        [18.93352632, 19.26508705, 16.88      ]])

# %%
reg.predict(X_test.iloc[:5,:])
# Out:
# array([25.9271049 , 38.48913878, 12.09805488, 23.52389065, 16.80033124])

# %%
final_layer_rfr = RandomForestRegressor(n_estimators=10, max_features=1, max_leaf_nodes=5,random_state=42)
final_layer_gbr = GradientBoostingRegressor(n_estimators=10, max_features=1, max_leaf_nodes=5,random_state=42)

final_layer = StackingRegressor(estimators=[('rf', final_layer_rfr),
                                            ('gbrt', final_layer_gbr)],
                                final_estimator=RidgeCV())

multi_layer_regressor = StackingRegressor(
    estimators=[('ridge', RidgeCV()),
                ('lasso', LassoCV(random_state=42)),
                ('knr', KNeighborsRegressor(n_neighbors=20,
                                            metric='euclidean'))],
    final_estimator=final_layer)

multi_layer_regressor.fit(X_train, y_train)
print('R2 score: {:.2f}'.format(multi_layer_regressor.score(X_test, y_test)))
# Out:
# R2 score: 0.78

# %%
for model in (final_layer_rfr, 
              final_layer_gbr, 
              RidgeCV(), 
              LassoCV(random_state=42),
              KNeighborsRegressor(n_neighbors=20,metric='euclidean')):
    model.fit(X_train, y_train)
    print(model.__class__)
    print('R2 score: {:.2f}'.format(model.score(X_test, y_test)))
# Out:
# <class 'sklearn.ensemble._forest.RandomForestRegressor'>
# R2 score: 0.52
# <class 'sklearn.ensemble._gb.GradientBoostingRegressor'>
# R2 score: 0.41
# <class 'sklearn.linear_model._ridge.RidgeCV'>
# R2 score: 0.68
# <class 'sklearn.linear_model._coordinate_descent.LassoCV'>
# R2 score: 0.66
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'>
# R2 score: 0.46

# %%
# Comparação com Regressor Tunado
base_model = GradientBoostingRegressor(random_state=42)

parameters={'n_estimators':[50,100,500], 
            'learning_rate': [0.1,0.05,0.02],
            'max_depth':[4,5,9], 
            'min_samples_leaf':[3,10,20], 
            'max_features':[1.0, 0.5] } 

regressor = GridSearchCV(base_model, parameters,cv=5, verbose=3,return_train_score=True)
regressor.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=50, score=(train=0.982, test=0.896), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=50, score=(train=0.981, test=0.786), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=50, score=(train=0.982, test=0.914), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=50, score=(train=0.979, test=0.897), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=50
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=50, score=(train=0.985, test=0.784), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=100, score=(train=0.992, test=0.898), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=100, score=(train=0.993, test=0.782), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=100, score=(train=0.993, test=0.919), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=100, score=(train=0.991, test=0.902), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=100, score=(train=0.994, test=0.793), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.896), total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.784), total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.917), total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.901), total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.792), total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=50, score=(train=0.956, test=0.890), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=50, score=(train=0.958, test=0.783), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=50, score=(train=0.957, test=0.900), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=50, score=(train=0.956, test=0.895), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=50, score=(train=0.969, test=0.754), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=100, score=(train=0.978, test=0.896), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=100, score=(train=0.979, test=0.779), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=100, score=(train=0.980, test=0.899), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=100, score=(train=0.975, test=0.903), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=100, score=(train=0.985, test=0.772), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=500, score=(train=0.999, test=0.894), total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=500, score=(train=0.999, test=0.768), total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=500, score=(train=0.999, test=0.896), total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=500, score=(train=0.999, test=0.902), total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=10, n_estimators=500, score=(train=1.000, test=0.769), total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=50, score=(train=0.929, test=0.886), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=50, score=(train=0.926, test=0.792), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=50, score=(train=0.923, test=0.889), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=50, score=(train=0.926, test=0.878), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=50, score=(train=0.943, test=0.707), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=100, score=(train=0.957, test=0.895), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=100, score=(train=0.957, test=0.801), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=100, score=(train=0.955, test=0.892), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=100, score=(train=0.957, test=0.889), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=100, score=(train=0.968, test=0.737), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=500, score=(train=0.995, test=0.896), total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=500, score=(train=0.996, test=0.798), total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=500, score=(train=0.995, test=0.892), total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=500, score=(train=0.994, test=0.903), total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=1.0, min_samples_leaf=20, n_estimators=500, score=(train=0.997, test=0.736), total=   0.4s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=50, score=(train=0.979, test=0.907), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=50, score=(train=0.976, test=0.808), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=50, score=(train=0.980, test=0.895), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=50, score=(train=0.977, test=0.886), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=50, score=(train=0.981, test=0.750), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=100, score=(train=0.991, test=0.910), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=100, score=(train=0.991, test=0.806), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=100, score=(train=0.992, test=0.902), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=100, score=(train=0.990, test=0.892), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=100, score=(train=0.993, test=0.759), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.907), total=   0.2s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.808), total=   0.2s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.902), total=   0.3s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.891), total=   0.2s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.751), total=   0.2s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=50, score=(train=0.954, test=0.895), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=50, score=(train=0.957, test=0.837), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=50, score=(train=0.956, test=0.905), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=50, score=(train=0.954, test=0.882), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=50, score=(train=0.966, test=0.740), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=100, score=(train=0.976, test=0.899), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=100, score=(train=0.977, test=0.829), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=100, score=(train=0.978, test=0.911), total=   0.1s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=100, score=(train=0.974, test=0.893), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=100, score=(train=0.983, test=0.759), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=500, score=(train=0.999, test=0.902), total=   0.2s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=500, score=(train=0.999, test=0.816), total=   0.2s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=500, score=(train=0.999, test=0.910), total=   0.2s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=500, score=(train=0.999, test=0.903), total=   0.2s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=10, n_estimators=500, score=(train=0.999, test=0.754), total=   0.2s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=50, score=(train=0.927, test=0.880), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=50, score=(train=0.932, test=0.819), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=50, score=(train=0.920, test=0.891), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=50, score=(train=0.918, test=0.869), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=50, score=(train=0.942, test=0.712), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=(train=0.953, test=0.891), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=(train=0.958, test=0.825), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=(train=0.952, test=0.899), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=(train=0.950, test=0.890), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=(train=0.966, test=0.738), total=   0.0s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=500, score=(train=0.994, test=0.895), total=   0.2s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=500, score=(train=0.995, test=0.837), total=   0.2s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=500, score=(train=0.994, test=0.897), total=   0.2s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=500, score=(train=0.993, test=0.911), total=   0.2s
# [CV] learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=4, max_features=0.5, min_samples_leaf=20, n_estimators=500, score=(train=0.996, test=0.736), total=   0.2s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=50, score=(train=0.992, test=0.885), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=50, score=(train=0.992, test=0.781), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=50, score=(train=0.993, test=0.905), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=50, score=(train=0.992, test=0.898), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=50, score=(train=0.993, test=0.771), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=100, score=(train=0.998, test=0.886), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=100, score=(train=0.998, test=0.780), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=100, score=(train=0.998, test=0.909), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=100, score=(train=0.998, test=0.899), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=100, score=(train=0.998, test=0.770), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.886), total=   0.5s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.779), total=   0.5s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.911), total=   0.5s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.899), total=   0.5s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.766), total=   0.5s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=50, score=(train=0.966, test=0.887), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=50, score=(train=0.968, test=0.783), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=50, score=(train=0.967, test=0.904), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=50, score=(train=0.964, test=0.893), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=50, score=(train=0.975, test=0.737), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=100, score=(train=0.984, test=0.889), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=100, score=(train=0.986, test=0.780), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=100, score=(train=0.985, test=0.903), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=100, score=(train=0.983, test=0.898), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=100, score=(train=0.989, test=0.754), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=500, score=(train=1.000, test=0.891), total=   0.4s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=500, score=(train=1.000, test=0.769), total=   0.4s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=500, score=(train=1.000, test=0.899), total=   0.4s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=500, score=(train=1.000, test=0.895), total=   0.4s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=10, n_estimators=500, score=(train=1.000, test=0.751), total=   0.4s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=50, score=(train=0.934, test=0.885), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=50, score=(train=0.940, test=0.804), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=50, score=(train=0.929, test=0.882), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=50, score=(train=0.929, test=0.890), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=50, score=(train=0.948, test=0.722), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=100, score=(train=0.963, test=0.892), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=100, score=(train=0.967, test=0.811), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=100, score=(train=0.961, test=0.891), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=100, score=(train=0.961, test=0.900), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=100, score=(train=0.971, test=0.743), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=500, score=(train=0.997, test=0.888), total=   0.4s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=500, score=(train=0.998, test=0.811), total=   0.4s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=500, score=(train=0.997, test=0.892), total=   0.4s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=500, score=(train=0.997, test=0.911), total=   0.4s
# [CV] learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=1.0, min_samples_leaf=20, n_estimators=500, score=(train=0.998, test=0.736), total=   0.4s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=50, score=(train=0.991, test=0.884), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=50, score=(train=0.991, test=0.797), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=50, score=(train=0.991, test=0.899), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=50, score=(train=0.988, test=0.889), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=50, score=(train=0.992, test=0.780), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=100, score=(train=0.997, test=0.887), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=100, score=(train=0.997, test=0.793), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=100, score=(train=0.997, test=0.905), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=100, score=(train=0.996, test=0.889), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=100, score=(train=0.998, test=0.780), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.886), total=   0.3s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.793), total=   0.3s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.905), total=   0.3s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.891), total=   0.3s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.778), total=   0.3s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=50, score=(train=0.965, test=0.892), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=50, score=(train=0.962, test=0.834), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=50, score=(train=0.964, test=0.905), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=50, score=(train=0.959, test=0.892), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=50, score=(train=0.974, test=0.718), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=100, score=(train=0.983, test=0.901), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=100, score=(train=0.984, test=0.828), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=100, score=(train=0.986, test=0.911), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=100, score=(train=0.981, test=0.903), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=100, score=(train=0.989, test=0.737), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=500, score=(train=1.000, test=0.904), total=   0.3s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=500, score=(train=1.000, test=0.826), total=   0.3s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=500, score=(train=1.000, test=0.907), total=   0.3s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=500, score=(train=1.000, test=0.904), total=   0.3s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=10, n_estimators=500, score=(train=1.000, test=0.728), total=   0.3s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=50, score=(train=0.935, test=0.880), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=50, score=(train=0.935, test=0.812), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=50, score=(train=0.930, test=0.900), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=50, score=(train=0.927, test=0.879), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=50, score=(train=0.950, test=0.713), total=   0.0s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=(train=0.963, test=0.893), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=(train=0.964, test=0.820), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=(train=0.961, test=0.909), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=(train=0.957, test=0.891), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=(train=0.972, test=0.735), total=   0.1s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=500, score=(train=0.997, test=0.900), total=   0.2s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=500, score=(train=0.997, test=0.820), total=   0.2s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=500, score=(train=0.997, test=0.909), total=   0.2s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=500, score=(train=0.996, test=0.913), total=   0.2s
# [CV] learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=5, max_features=0.5, min_samples_leaf=20, n_estimators=500, score=(train=0.998, test=0.730), total=   0.2s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=50, score=(train=0.999, test=0.886), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=50, score=(train=0.999, test=0.770), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=50, score=(train=0.999, test=0.889), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=50, score=(train=0.999, test=0.887), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=50, score=(train=0.999, test=0.731), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=100, score=(train=1.000, test=0.888), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=100, score=(train=1.000, test=0.771), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=100, score=(train=1.000, test=0.891), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=100, score=(train=1.000, test=0.888), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=100, score=(train=1.000, test=0.732), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.889), total=   0.7s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.772), total=   0.7s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.890), total=   0.6s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.888), total=   0.6s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.729), total=   0.7s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=10, n_estimators=50, score=(train=0.976, test=0.877), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=10, n_estimators=50, score=(train=0.979, test=0.782), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=10, n_estimators=50, score=(train=0.975, test=0.905), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=10, n_estimators=50, score=(train=0.976, test=0.900), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=10, n_estimators=50, score=(train=0.985, test=0.755), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=10, n_estimators=100, score=(train=0.991, test=0.881), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=10, n_estimators=100, score=(train=0.993, test=0.774), total=   0.1s
# [CV] learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.1, max_depth=9, max_features=1.0, min_samples_leaf=10, n_estimators=100, score=(train=0.991, test=0.906), total=   0.1s
# ...
# [CV] learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=50, score=(train=0.736, test=0.669), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=50, score=(train=0.738, test=0.693), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=50, score=(train=0.723, test=0.696), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=50, score=(train=0.726, test=0.729), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=50, score=(train=0.754, test=0.606), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=100, score=(train=0.873, test=0.821), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=100, score=(train=0.875, test=0.786), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=100, score=(train=0.866, test=0.836), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=100, score=(train=0.862, test=0.843), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=100, score=(train=0.891, test=0.681), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=500, score=(train=0.969, test=0.888), total=   0.5s
# [CV] learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=500, score=(train=0.970, test=0.807), total=   0.5s
# [CV] learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=500, score=(train=0.968, test=0.892), total=   0.5s
# [CV] learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=500, score=(train=0.964, test=0.904), total=   0.5s
# [CV] learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=1.0, min_samples_leaf=20, n_estimators=500, score=(train=0.976, test=0.745), total=   0.5s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=50, score=(train=0.842, test=0.722), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=50, score=(train=0.845, test=0.739), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=50, score=(train=0.841, test=0.740), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=50, score=(train=0.836, test=0.742), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=50, score=(train=0.846, test=0.643), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=100, score=(train=0.971, test=0.852), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=100, score=(train=0.972, test=0.825), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=100, score=(train=0.970, test=0.868), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=100, score=(train=0.969, test=0.862), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=100, score=(train=0.973, test=0.720), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.889), total=   0.4s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.825), total=   0.4s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.909), total=   0.4s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.899), total=   0.4s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=3, n_estimators=500, score=(train=1.000, test=0.733), total=   0.4s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=50, score=(train=0.778, test=0.698), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=50, score=(train=0.776, test=0.730), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=50, score=(train=0.766, test=0.719), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=50, score=(train=0.764, test=0.726), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=50, score=(train=0.796, test=0.621), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=100, score=(train=0.919, test=0.846), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=100, score=(train=0.921, test=0.829), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=100, score=(train=0.914, test=0.861), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=100, score=(train=0.911, test=0.860), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=100, score=(train=0.935, test=0.710), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=500, score=(train=0.991, test=0.907), total=   0.3s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=500, score=(train=0.993, test=0.825), total=   0.3s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=500, score=(train=0.992, test=0.918), total=   0.3s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=500, score=(train=0.990, test=0.913), total=   0.3s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=10, n_estimators=500, score=(train=0.995, test=0.762), total=   0.3s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=50, score=(train=0.729, test=0.665), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=50, score=(train=0.726, test=0.704), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=50, score=(train=0.713, test=0.687), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=50, score=(train=0.715, test=0.695), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=50
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=50, score=(train=0.745, test=0.567), total=   0.0s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=(train=0.875, test=0.814), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=(train=0.875, test=0.808), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=(train=0.864, test=0.844), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=(train=0.861, test=0.833), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=100
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=100, score=(train=0.888, test=0.673), total=   0.1s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=500, score=(train=0.969, test=0.894), total=   0.3s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=500, score=(train=0.971, test=0.834), total=   0.3s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=500, score=(train=0.967, test=0.909), total=   0.3s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=500, score=(train=0.965, test=0.899), total=   0.3s
# [CV] learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=500
# [CV]  learning_rate=0.02, max_depth=9, max_features=0.5, min_samples_leaf=20, n_estimators=500, score=(train=0.974, test=0.729), total=   0.3s
# [Parallel(n_jobs=1)]: Done 810 out of 810 | elapsed:  2.2min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0,
#                                                  criterion='friedman_mse',
#                                                  init=None, learning_rate=0.1,
#                                                  loss='ls', max_depth=3,
#                                                  max_features=None,
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weight_fraction_leaf=0.0,
#                                                  n_estimators=100,
#                                                  n_iter_n...
#                                                  random_state=42, subsample=1.0,
#                                                  tol=0.0001,
#                                                  validation_fraction=0.1,
#                                                  verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.1, 0.05, 0.02],
#                          'max_depth': [4, 5, 9], 'max_features': [1.0, 0.5],
#                          'min_samples_leaf': [3, 10, 20],
#                          'n_estimators': [50, 100, 500]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring=None, verbose=3)

# %%
print('R2 score: {:.2f}'.format(regressor.best_estimator_.score(X_test, y_test)))
# Out:
# R2 score: 0.85

# %% [markdown]
# Portanto, um Gradient Boosting tunado performou melhor do stacking de modelos default.

# %%
# sorted(regressor.cv_results_.keys())

results_cv = pd.DataFrame(regressor.cv_results_)
results_cv.sort_values(by='rank_test_score', ascending=True).head(3).T
# Out:
#                                                                       104  \
# mean_fit_time                                                    0.335303
# std_fit_time                                                     0.003116
# mean_score_time                                                  0.002992
# std_score_time                                                        0.0
# param_learning_rate                                                  0.05
# param_max_depth                                                         9
# param_max_features                                                    0.5
# param_min_samples_leaf                                                 10
# param_n_estimators                                                    500
# params                  {'learning_rate': 0.05, 'max_depth': 9, 'max_f...
# split0_test_score                                                0.911067
# split1_test_score                                                0.848183
# split2_test_score                                                0.916128
# split3_test_score                                                 0.90203
# split4_test_score                                                0.757057
# mean_test_score                                                  0.866893
# std_test_score                                                    0.06004
# rank_test_score                                                         1
# split0_train_score                                               0.998942
# split1_train_score                                               0.999367
# split2_train_score                                               0.999338
# split3_train_score                                               0.998846
# split4_train_score                                               0.999613
# mean_train_score                                                 0.999221
# std_train_score                                                  0.000285
#
#                                                                       137  \
# mean_fit_time                                                    0.283626
# std_fit_time                                                     0.010509
# mean_score_time                                                  0.002202
# std_score_time                                                   0.000395
# param_learning_rate                                                  0.02
# param_max_depth                                                         5
# param_max_features                                                    0.5
# param_min_samples_leaf                                                  3
# param_n_estimators                                                    500
# params                  {'learning_rate': 0.02, 'max_depth': 5, 'max_f...
# split0_test_score                                                0.904232
# split1_test_score                                                0.838085
# split2_test_score                                                0.909208
# split3_test_score                                                0.907204
# split4_test_score                                                 0.77007
# mean_test_score                                                   0.86576
# std_test_score                                                   0.054787
# rank_test_score                                                         2
# split0_train_score                                               0.997325
# split1_train_score                                               0.997494
# split2_train_score                                               0.997455
# split3_train_score                                               0.996261
# split4_train_score                                               0.997814
# mean_train_score                                                  0.99727
# std_train_score                                                  0.000529
#
#                                                                       119
# mean_fit_time                                                    0.243748
# std_fit_time                                                     0.002721
# mean_score_time                                                  0.002194
# std_score_time                                                   0.000399
# param_learning_rate                                                  0.02
# param_max_depth                                                         4
# param_max_features                                                    0.5
# param_min_samples_leaf                                                  3
# param_n_estimators                                                    500
# params                  {'learning_rate': 0.02, 'max_depth': 4, 'max_f...
# split0_test_score                                                0.898987
# split1_test_score                                                0.828139
# split2_test_score                                                0.911402
# split3_test_score                                                0.904334
# split4_test_score                                                0.782469
# mean_test_score                                                  0.865067
# std_test_score                                                    0.05104
# rank_test_score                                                         3
# split0_train_score                                               0.992027
# split1_train_score                                               0.991714
# split2_train_score                                               0.991693
# split3_train_score                                               0.988783
# split4_train_score                                               0.993264
# mean_train_score                                                 0.991496
# std_train_score                                                  0.001474

# %%
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.05, loss='ls', max_depth=9,
#                           max_features=0.5, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=10, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=500,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=42, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)
