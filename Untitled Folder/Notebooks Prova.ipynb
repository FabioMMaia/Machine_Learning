# %% [markdown]
# # Importações

# %%
# GERAL
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
# Out:
# C:\Users\fabio\AppData\Roaming\Python\Python37\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# MODELAGEM
# import sklearn
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score,cross_validate
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold

# %%
# MODELOS -  SUPERVISIONADO

# REGRESSÃO
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor
from xgboost import XGBRegressor

# CLASSIFICAÇÃO
# Knn
from sklearn.neighbors import KNeighborsClassifier

# Regressão Logística
from sklearn.linear_model import LogisticRegression

# Naive Bayes
from sklearn.naive_bayes import GaussianNB

# SVM
from sklearn.svm import SVC

# Arvores de Decisão (Classificação)
from sklearn.tree import DecisionTreeClassifier

# Ensembles
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from xgboost import XGBClassifier
import lightgbm

# %%
# MODELOS - NÃO SUPERVISIONADO

#Kmeans
from sklearn.cluster import KMeans

# Hierarquico
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as sch

# DBSCAN
from sklearn.cluster import DBSCAN

# HDBSCAN
import hdbscan
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-88fe9ba0dedc> in <module>
#      12
#      13 # HDBSCAN
# ---> 14 import hdbscan
#
# ModuleNotFoundError: No module named 'hdbscan'

# %%
# MÉTRICAS
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import log_loss
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import mean_squared_error as MSE

# %%
# DATASETS
from sklearn.datasets import load_breast_cancer
from sklearn.datasets import load_iris
from sklearn.datasets import load_boston
from sklearn.datasets import load_diabetes

# %%
# DATASETS -  NÃO SUPERVISIONADO
from sklearn.datasets import make_moons

# %%
load_df = load_breast_cancer()
dataset = pd.concat([pd.DataFrame(load_df.data,columns = load_df.feature_names)
                     ,pd.DataFrame(load_df.target,columns = ['target'])], axis=1)

# Salva e carrega a base
# dataset.to_csv(r'.\data\base.csv')
# df = pd.read_csv(r'.\data\base.csv')

# %%
dataset.describe(include='all')
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
X = dataset.drop(columns='target')
y = dataset[['target']]

# %%
classifier= KNeighborsClassifier(n_neighbors=10)
classifier= LogisticRegression(penalty='l2',C=0.1, max_iter=-1)
classifier= DecisionTreeClassifier(criterion='entropy',max_depth=3)
classifier = RandomForestClassifier(n_estimators=100,max_depth=8,min_samples_leaf=8,random_state=3)
classifier= GradientBoostingClassifier(n_estimators=100,max_depth=8,min_samples_leaf=8,random_state=3)
classifier=GaussianNB()
classifier= SVC()
classifier = XGBClassifier()

# %%
classifier= LogisticRegression(penalty='l2',C=0.1, max_iter=10E6)
# results = cross_val_score(classifier, X, y, cv=10,  return_train_score=True)
results = cross_validate(classifier, X, y, cv=10, scoring='roc_auc', return_train_score=True)

# %%
results_df= pd.DataFrame(results)

print('Média no teste:',results_df.test_score.mean())
print('Média no treino:',results_df.train_score.mean())

results_df.head()
# Out:
# Média no teste: 0.9922122586408302
# Média no treino: 0.9931961796296097
#    fit_time  score_time  test_score  train_score
# 0  0.230108    0.000000    0.997403     0.992759
# 1  0.249913    0.000000    0.989610     0.993233
# 2  0.307048    0.001995    0.990741     0.993362
# 3  0.233335    0.001995    0.990741     0.993476
# 4  0.244878    0.015622    0.998677     0.992253

# %%
classifier.fit(X_train, y_train)
y_pred = classifier.predict_(X_test)
